# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#import some relative libraries
import pandas as pd
import numpy as np
import math
from numbers import Number
from scipy import stats

from sklearn.base import BaseEstimator, TransformerMixin


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.feature_selection import SelectFromModel

from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score, auc, ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix, RocCurveDisplay, classification_report
from sklearn.metrics import precision_score, recall_score, accuracy_score

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %%
#load in the data from an excel file and save in a pandas dataset
#preview the data
bean_df= pd.read_excel('my_data/Dry_Bean_Dataset.xlsx')
bean_df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER
# 3     0.928329      0.007017      0.003215      0.861794      0.994199  SEKER
# 4     0.970516      0.006697      0.003665      0.941900      0.999166  SEKER

# %%
#check for data types and see if information is missing
bean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
#  16  Class            13611 non-null  object
# dtypes: float64(14), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
#column information and dataset taken from
#https://archive.ics.uci.edu/dataset/602/dry+bean+dataset
#column information
"""
1.) Area (A): The area of a bean zone and the number of pixels within its boundaries.
2.) Perimeter (P): Bean circumference is defined as the length of its border.
3.) Major axis length (L): The distance between the ends of the longest line that can be drawn from a bean.
4.) Minor axis length (l): The longest line that can be drawn from the bean while standing perpendicular to the main axis.
5.) Aspect ratio (K): Defines the relationship between L and l.
6.) Eccentricity (Ec): Eccentricity of the ellipse having the same moments as the region.
7.) Convex area (C): Number of pixels in the smallest convex polygon that can contain the area of a bean seed.
8.) Equivalent diameter (Ed): The diameter of a circle having the same area as a bean seed area.
9.) Extent (Ex): The ratio of the pixels in the bounding box to the bean area.
10.)Solidity (S): Also known as convexity. The ratio of the pixels in the convex shell to those found in beans.
11.)Roundness (R): Calculated with the following formula: (4piA)/(P^2)
12.)Compactness (CO): Measures the roundness of an object: Ed/L
13.)ShapeFactor1 (SF1)
14.)ShapeFactor2 (SF2)
15.)ShapeFactor3 (SF3)
16.)ShapeFactor4 (SF4)
17.)Class (Seker, Barbunya, Bombay, Cali, Dermosan, Horoz and Sira)
"""
# Out:
# '\n1.) Area (A): The area of a bean zone and the number of pixels within its boundaries.\n2.) Perimeter (P): Bean circumference is defined as the length of its border.\n3.) Major axis length (L): The distance between the ends of the longest line that can be drawn from a bean.\n4.) Minor axis length (l): The longest line that can be drawn from the bean while standing perpendicular to the main axis.\n5.) Aspect ratio (K): Defines the relationship between L and l.\n6.) Eccentricity (Ec): Eccentricity of the ellipse having the same moments as the region.\n7.) Convex area (C): Number of pixels in the smallest convex polygon that can contain the area of a bean seed.\n8.) Equivalent diameter (Ed): The diameter of a circle having the same area as a bean seed area.\n9.) Extent (Ex): The ratio of the pixels in the bounding box to the bean area.\n10.)Solidity (S): Also known as convexity. The ratio of the pixels in the convex shell to those found in beans.\n11.)Roundness (R): Calculated with the following formula: (4piA)/(P^2)\n12.)Compactness (CO): Measures the roundness of an object: Ed/L\n13.)ShapeFactor1 (SF1)\n14.)ShapeFactor2 (SF2)\n15.)ShapeFactor3 (SF3)\n16.)ShapeFactor4 (SF4)\n17.)Class (Seker, Barbunya, Bombay, Cali, Dermosan, Horoz and Sira)\n'

# %%
bean_df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064220      0.749733
# std        0.246678      0.092002   29774.915817      59.177120      0.049086
# min        1.024868      0.218951   20684.000000     161.243764      0.555315
# 25%        1.432307      0.715928   36714.500000     215.068003      0.718634
# 50%        1.551124      0.764441   45178.000000     238.438026      0.759859
# 75%        1.707109      0.810466   62294.000000     279.446467      0.786851
# max        2.430306      0.911423  263261.000000     569.374358      0.866195
#
#            Solidity     roundness   Compactness  ShapeFactor1  ShapeFactor2  \
# count  13611.000000  13611.000000  13611.000000  13611.000000  13611.000000
# mean       0.987143      0.873282      0.799864      0.006564      0.001716
# std        0.004660      0.059520      0.061713      0.001128      0.000596
# min        0.919246      0.489618      0.640577      0.002778      0.000564
# 25%        0.985670      0.832096      0.762469      0.005900      0.001154
# 50%        0.988283      0.883157      0.801277      0.006645      0.001694
# 75%        0.990013      0.916869      0.834270      0.007271      0.002170
# max        0.994677      0.990685      0.987303      0.010451      0.003665
#
#        ShapeFactor3  ShapeFactor4
# count  13611.000000  13611.000000
# mean       0.643590      0.995063
# std        0.098996      0.004366
# min        0.410339      0.947687
# 25%        0.581359      0.993703
# 50%        0.642044      0.996386
# 75%        0.696006      0.997883
# max        0.974767      0.999733

# %%
#lambda function creating column showing if instance is or isn't the target bean
bean_df['Dermason']= bean_df['Class'].apply(lambda x: 1 if x == 'DERMASON' else 0) 
bean_df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class  \
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER
# 3     0.928329      0.007017      0.003215      0.861794      0.994199  SEKER
# 4     0.970516      0.006697      0.003665      0.941900      0.999166  SEKER
#
#    Dermason
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
#check to make sure this new Dermason column proportion matches the above proportion
bean_df['Dermason'].value_counts(normalize=True)
# Out:
# Dermason
# 0    0.739475
# 1    0.260525
# Name: proportion, dtype: float64

# %%
#assign the independent variable columns
X= bean_df.drop(['Dermason','Class'], axis = 1)
#assign the dependant variable columns
y= bean_df['Dermason']

#split up the data into train and test subsets
X_train, X_test, y_train, y_test= train_test_split(X, y, random_state= 24, test_size= 0.1)

# %%
#check out the data distrobutions
#Create a figure to hold all subplots
fig, ax = plt.subplots(4, 4, figsize=(15, 15))

#Flatten the axes array to easily iterate over
ax = ax.flatten()

#Plot the original data
for i, col in enumerate(X_train.columns):
    sns.histplot(X_train[col], kde=True, color='blue', ax=ax[i])
    ax[i].set_title(f'Original: {col}')
    ax[i].set_xlabel(col)
    ax[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
def TransShift(df):
    
    LogT = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength', 'ConvexArea',
            'EquivDiameter', 'ShapeFactor2']

    BoxCoxT = ['Eccentricity', 'Solidity', 'roundness', 'ShapeFactor4']

    Redist = pd.DataFrame()

    for col in df.columns:

        if col in LogT:
            Redist[col] = np.log1p(df[col])

        elif col in BoxCoxT:
            min_val = df[col].min()
            if min_val <= 0:
                shifted_col = df[col] - min_val + 1
            else:
                shifted_col = df[col]

            Redist[col], _ = stats.boxcox(shifted_col)

        else:
            Redist[col] = df[col]

    return Redist

# %%
X_train_Norm= TransShift(X_train)

# %%
#Create a figure to hold all subplots
fig, ax = plt.subplots(4, 4, figsize=(15, 15))

#Flatten the axes array to easily iterate over
ax = ax.flatten()

#Plot the original data
for i, col in enumerate(X_train_Norm.columns):
    sns.histplot(X_train_Norm[col], kde=True, color='blue', ax=ax[i])
    ax[i].set_title(f'Original: {col}')
    ax[i].set_xlabel(col)
    ax[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# create a class to iterate through all of the potential options for the different classifier options

# %%
class ModelWithCV():
    def __init__(self, model_instantiator, model_name, X, y, model_kwargs = {},\
                 scaler=False, smote_and_rand_und= False, cv_now=True):
        self.model_instatiator = model_instantiator
        self.model = None
        self.model_kwargs = model_kwargs
        self.name = model_name
        self.scaler= scaler
        self.smote_and_rand_und= smote_and_rand_und
        self.X = X
        self.y = y
        self.cv_specificity_mean = None
        self.cv_precision_mean = None
        self.cv_recall_mean = None
        self.avg_conf_matrix = None
       
        self.cv_specificity_mean_train = None
        self.cv_precision_mean_train = None
        self.cv_recall_mean_train = None
        self.avg_conf_matrix_train = None
        if cv_now:
            self.cross_validate()

    def cross_validate(self, X=None, y=None, kfolds=10):
  
        cv_X = X if X else self.X
        cv_y = y if y else self.y

        cv_X = cv_X.values if isinstance(cv_X, pd.DataFrame) else cv_X
        cv_y = cv_y.values if isinstance(cv_y, pd.Series) else cv_y

        cv_splits = StratifiedKFold(n_splits=kfolds)
        specificity_scores_train = []
        precision_scores_train = []
        recall_scores_train = []
        specificity_scores = []
        precision_scores = []
        recall_scores = []
        total_conf_matrix = np.zeros((2, 2))  
        total_conf_matrix_train = np.zeros((2, 2))  

        if self.scaler:
            print('Scaling')

        if self.smote_and_rand_und:
            print('SMOTEing and Randomly Undersampling')
        
        for train_idx, test_idx in cv_splits.split(cv_X, cv_y):
            X_train, X_test = cv_X[train_idx], cv_X[test_idx]
            y_train, y_test = cv_y[train_idx], cv_y[test_idx]
                    
            self.model = self.model_instatiator(random_state= 24, **self.model_kwargs)
            
            if self.scaler:
                cv_scaler= self.scaler
                X_train = cv_scaler.fit_transform(X_train)
                X_test = cv_scaler.transform(X_test)

            if self.smote_and_rand_und:
                smote = SMOTE(sampling_strategy='auto', random_state=24)  
                undersample = RandomUnderSampler(sampling_strategy='auto', random_state=24)
                pipeline = Pipeline(steps=[('smote', smote), ('undersample', undersample)])
        
                X_train, y_train = pipeline.fit_resample(X_train, y_train)
        
            self.model.fit(X_train, y_train)
           
            y_train_pred = self.model.predict(X_train)
            y_pred = self.model.predict(X_test)

            TN_train, FP_train, FN_train, TP_train = confusion_matrix(y_train, y_train_pred).ravel()
            total_conf_matrix_train += confusion_matrix(y_train, y_train_pred)
            specificity_train = TN_train / (TN_train + FP_train) 
            specificity_scores_train.append(specificity_train)
            precision_train = precision_score(y_train, y_train_pred)
            recall_train = recall_score(y_train, y_train_pred)
            precision_scores_train.append(precision_train)
            recall_scores_train.append(recall_train)

            #validation set
            TN, FP, FN, TP = confusion_matrix(y_test, y_pred).ravel()
            total_conf_matrix += confusion_matrix(y_test, y_pred)

            specificity = TN / (TN + FP)  
            specificity_scores.append(specificity)
            precision = precision_score(y_test, y_pred)
            recall = recall_score(y_test, y_pred)
            precision_scores.append(precision)
            recall_scores.append(recall)

        self.cv_specificity_mean_train = np.mean(specificity_scores_train)
        self.cv_precision_mean_train = np.mean(precision_scores_train)
        self.cv_recall_mean_train = np.mean(recall_scores_train)
        self.avg_conf_matrix_train = total_conf_matrix_train / kfolds
        self.cv_specificity_mean = np.mean(specificity_scores)
        self.cv_precision_mean = np.mean(precision_scores)
        self.cv_recall_mean = np.mean(recall_scores)
        self.avg_conf_matrix = total_conf_matrix / kfolds

    def print_cv_summary(self):
        cv_summary_train = (
            f"CV results for {self.name} model:"
            f"Average specificity: {self.cv_specificity_mean_train:.5f}\n"
            f"Average precision: {self.cv_precision_mean_train:.5f}\n"
            f"Average recall: {self.cv_recall_mean_train:.5f}")
        print('###TRAIN###')
        print(cv_summary_train)
       
        cv_summary_val = (
            f"CV results for {self.name} model:"
            f"Average specificity: {self.cv_specificity_mean:.5f}\n"
            f"Average precision: {self.cv_precision_mean:.5f}\n"
            f"Average recall: {self.cv_recall_mean:.5f}")
        print('###VAL###')
        print(cv_summary_val)

        return self.cv_specificity_mean, self.cv_precision_mean, self.cv_recall_mean, \
        self.model_kwargs, self.scaler, self.smote_and_rand_und
    

    def plot_avg_conf_matrix(self):
        if self.avg_conf_matrix is not None:
            disp = ConfusionMatrixDisplay(confusion_matrix=self.avg_conf_matrix_train)
            disp.plot(cmap=plt.cm.Blues, values_format='.2f')
            plt.title(f"Average Train Confusion Matrix for {self.name}")
            plt.show()
           
            disp = ConfusionMatrixDisplay(confusion_matrix=self.avg_conf_matrix)
            disp.plot(cmap=plt.cm.Blues, values_format='.2f')
            plt.title(f"Average Confusion Matrix for {self.name}")
            plt.show()

# %% [markdown]
# ## print logistic regression baseline model results

# %%
LR_Baseline_Results= ModelWithCV(model_instantiator= LogisticRegression,
                                    model_name= 'LR_Base_Model',
                                    X= X_train,
                                    y= y_train,
                                    scaler= False,
                                    smote_and_rand_und= False
                                   )

LR_Baseline_Results.plot_avg_conf_matrix()

LR_Baseline_Results.print_cv_summary()
# Out:
# ###TRAIN###
# CV results for LR_Base_Model model:Average specificity: 0.96146
# Average precision: 0.88582
# Average recall: 0.85499
# ###VAL###
# CV results for LR_Base_Model model:Average specificity: 0.96187
# Average precision: 0.88769
# Average recall: 0.85613
# (0.9618657383347337, 0.887693568491631, 0.8561286034561435, {}, False, False)

# %% [markdown]
# ## print decision tree baseline model results

# %%
#instantiate the class
DT_Baseline_Results= ModelWithCV(model_instantiator= DecisionTreeClassifier,
                                    model_name= 'DT_Base_Model',
                                    X= X_train,
                                    y= y_train,
                                    scaler= False,
                                    smote_and_rand_und= False
                                   )

DT_Baseline_Results.plot_avg_conf_matrix()

print('results for lr baseline:')
LR_Baseline_Results.print_cv_summary()
print()
print('results for dt baseline:')
DT_Baseline_Results.print_cv_summary()
# Out:
# results for lr baseline:
# ###TRAIN###
# CV results for LR_Base_Model model:Average specificity: 0.96146
# Average precision: 0.88582
# Average recall: 0.85499
# ###VAL###
# CV results for LR_Base_Model model:Average specificity: 0.96187
# Average precision: 0.88769
# Average recall: 0.85613
#
# results for dt baseline:
# ###TRAIN###
# CV results for DT_Base_Model model:Average specificity: 1.00000
# Average precision: 1.00000
# Average recall: 1.00000
# ###VAL###
# CV results for DT_Base_Model model:Average specificity: 0.96352
# Average precision: 0.89575
# Average recall: 0.89389
# (0.9635192992340533, 0.8957492446149351, 0.8938872686149635, {}, False, False)

# %% [markdown]
# unlike the logistic regression model, the current decision tree model is clearly overfitting to the training data, but the decision tree model's validation set is outperforming both the training and validation set of the logistic regression model.
#
# lets run an optimization grid search on both of these models to see which of the two perform the best after being properly tuned to the dataset.

# %% [markdown]
# ## tune logistic regression via grid search

# %% [markdown]
# This search scale has been narrowed down to parameters previously discovered to be effective, while still demonstrating the effectiveness and utility of the code. This is because previous wider searches have proven to be too computationally expensive for my current computer to handle, and cause the notebook to significantly slow down and or crash. One potential way to mitigate this would be to split up the grid search to tune for one parameter at a time.

# %%
lr_metric_tracker= []
lr_data_and_scaler= []

data_sets= [X_train, X_train_Norm]
C= [1, 10, 10000, 100000]
int_fit= [True, False]
solvers = ['liblinear', 'saga']
smote= [True, False]
scaler= [False, MinMaxScaler()]

for data, data_name in zip(data_sets, ["X_train", "X_train_Norm"]):
    for fit in int_fit:
        for sm in smote:
            for sc in scaler:        
                for c in C:
                    for solvera in solvers:
                        model_kwargs= {'C': c, 'solver': solvera, 'fit_intercept': fit, 'penalty': 'l2' }
                        print(model_kwargs)
                        temp= ModelWithCV(model_instantiator= LogisticRegression,
                                                            model_name= 'Tuned_LR_Model',
                                                            X= data,
                                                            y= y_train,
                                                            scaler= sc,
                                                            smote_and_rand_und= sm,
                                                            model_kwargs= model_kwargs
                                                           )
                        
                        lr_metric_tracker.append(temp.print_cv_summary())
                        lr_data_and_scaler.append((data_name, sc))
                        
                        print()
                        print('#### NEXT ITERATION###')
# Out:
# {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.90486
# Average precision: 0.90594
# Average recall: 0.91635
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.90466
# Average precision: 0.77059
# Average recall: 0.91309
#
# #### NEXT ITERATION###
# {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 1.00000
# Average precision: 1.00000
# Average recall: 0.00451
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 1.00000
# Average precision: 0.90000
# Average recall: 0.00441
#
# #### NEXT ITERATION###
# {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.90458
# Average precision: 0.90569
# Average recall: 0.91638
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.90323
# Average precision: 0.76799
# Average recall: 0.91309
#
# #### NEXT ITERATION###
# {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 1.00000
# Average precision: 1.00000
# Average recall: 0.00451
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 1.00000
# Average precision: 0.90000
# Average recall: 0.00441
#
# #### NEXT ITERATION###
# {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.90501
# Average precision: 0.90607
# Average recall: 0.91633
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.90488
# Average precision: 0.77102
# Average recall: 0.91309
#
# #### NEXT ITERATION###
# {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 1.00000
# Average precision: 1.00000
# Average recall: 0.00451
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 1.00000
# Average precision: 0.90000
# Average recall: 0.00441
#
# #### NEXT ITERATION###
# {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.90487
# Average precision: 0.90595
# Average recall: 0.91633
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.90466
# Average precision: 0.77061
# Average recall: 0.91309
#
# #### NEXT ITERATION###
# {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 1.00000
# Average precision: 1.00000
# Average recall: 0.00451
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 1.00000
# Average precision: 0.90000
# Average recall: 0.00441
#
# #### NEXT ITERATION###
# {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# Scaling
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.94299
# Average precision: 0.94373
# Average recall: 0.95610
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.94258
# Average precision: 0.85277
# Average recall: 0.94679
#
# #### NEXT ITERATION###
# {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# Scaling
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.94315
# Average precision: 0.94387
# Average recall: 0.95601
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.94324
# Average precision: 0.85447
# Average recall: 0.94804
#
# #### NEXT ITERATION###
# {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# Scaling
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.94913
# Average precision: 0.94982
# Average recall: 0.96286
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.94897
# Average precision: 0.86794
# Average recall: 0.95403
#
# #### NEXT ITERATION###
# {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# Scaling
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.94921
# Average precision: 0.94989
# Average recall: 0.96280
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.94875
# Average precision: 0.86740
# Average recall: 0.95340
#
# #### NEXT ITERATION###
# {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# Scaling
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.95115
# Average precision: 0.95183
# Average recall: 0.96529
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.95063
# Average precision: 0.87204
# Average recall: 0.95718
#
# #### NEXT ITERATION###
# {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# Scaling
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.95165
# Average precision: 0.95227
# Average recall: 0.96453
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.95173
# Average precision: 0.87451
# Average recall: 0.95718
#
# #### NEXT ITERATION###
# {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# Scaling
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.95115
# Average precision: 0.95185
# Average recall: 0.96572
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.95074
# Average precision: 0.87221
# Average recall: 0.95655
#
# #### NEXT ITERATION###
# {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# Scaling
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.95164
# Average precision: 0.95225
# Average recall: 0.96453
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.95173
# Average precision: 0.87451
# Average recall: 0.95718
#
# #### NEXT ITERATION###
# {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.
'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# Scaling
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.97558
# Average precision: 0.92762
# Average recall: 0.89403
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.97553
# Average precision: 0.92767
# Average recall: 0.89232
#
# #### NEXT ITERATION###

# %%
pd.set_option('display.max_colwidth', None)

# %%
lr_metrics_df= pd.DataFrame(lr_metric_tracker)

lr_data_scaler_df= pd.DataFrame(lr_data_and_scaler)

lr_tuned_results_df = pd.merge(lr_metrics_df, lr_data_scaler_df, left_index=True, right_index=True)

print(len(lr_tuned_results_df))

lr_tuned_results_df.head()
# Out:
# 128
#         0_x       1_x         2  \
# 0  0.904663  0.770589  0.913092
# 1  1.000000  0.900000  0.004410
# 2  0.903230  0.767993  0.913092
# 3  1.000000  0.900000  0.004410
# 4  0.904884  0.771019  0.913092
#
#                                                                              3  \
# 0      {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 1           {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 2     {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 3          {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 4  {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
#
#        4     5      0_y    1_y
# 0  False  True  X_train  False
# 1  False  True  X_train  False
# 2  False  True  X_train  False
# 3  False  True  X_train  False
# 4  False  True  X_train  False

# %%
lr_new_col_names= ['v_avg_spec', 'v_avg_prec', 'v_avg_rec', 'v_hyp_para', 'scaler', 'v_SM_RU', 'normalized', 'scaled']

lr_tuned_results_df.columns= lr_new_col_names

lr_tuned_results_df.head()
# Out:
#    v_avg_spec  v_avg_prec  v_avg_rec  \
# 0    0.904663    0.770589   0.913092
# 1    1.000000    0.900000   0.004410
# 2    0.903230    0.767993   0.913092
# 3    1.000000    0.900000   0.004410
# 4    0.904884    0.771019   0.913092
#
#                                                                     v_hyp_para  \
# 0      {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 1           {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 2     {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 3          {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 4  {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
#
#   scaler  v_SM_RU normalized scaled
# 0  False     True    X_train  False
# 1  False     True    X_train  False
# 2  False     True    X_train  False
# 3  False     True    X_train  False
# 4  False     True    X_train  False

# %%
#sort by highest spec value
lr_tuned_grid_search_spec_sorted = lr_tuned_results_df.sort_values(\
    by=['v_avg_spec', 'v_avg_prec', 'v_avg_rec'], ascending=[False, False, False])

pd.set_option('display.max_rows', None)

lr_tuned_grid_search_spec_sorted
# Out:
#      v_avg_spec  v_avg_prec  v_avg_rec  \
# 1      1.000000    0.900000   0.004410
# 3      1.000000    0.900000   0.004410
# 5      1.000000    0.900000   0.004410
# 7      1.000000    0.900000   0.004410
# 33     1.000000    0.900000   0.004410
# 35     1.000000    0.900000   0.004410
# 37     1.000000    0.900000   0.004410
# 39     1.000000    0.900000   0.004410
# 17     1.000000    0.000000   0.000000
# 19     1.000000    0.000000   0.000000
# 21     1.000000    0.000000   0.000000
# 23     1.000000    0.000000   0.000000
# 49     1.000000    0.000000   0.000000
# 51     1.000000    0.000000   0.000000
# 53     1.000000    0.000000   0.000000
# 55     1.000000    0.000000   0.000000
# 82     0.979831    0.933961   0.811720
# 114    0.978949    0.927953   0.772675
# 56     0.976966    0.929386   0.861462
# 57     0.976966    0.929386   0.861462
# 24     0.976855    0.928979   0.860518
# 25     0.976745    0.928565   0.859885
# 125    0.975533    0.927688   0.892632
# 127    0.975533    0.927672   0.892318
# 91     0.975533    0.926914   0.882556
# 73     0.938501    0.842059   0.933246
# 104    0.937289    0.839103   0.929469
# 105    0.937289    0.839103   0.929469
# 66     0.932439    0.830608   0.942058
# 98     0.918111    0.800238   0.934504
# 4      0.904884    0.771019   0.913092
# 34     0.904774    0.770814   0.913092
# 38     0.904774    0.770814   0.913092
# 36     0.904774    0.770812   0.913092
# 6      0.904663    0.770610   0.913092
# 0      0.904663    0.770589   0.913092
# 32     0.904553    0.770384   0.913092
# 2      0.903230    0.767993   0.913092
# 64     0.860357    0.695361   0.909005
# 69     0.832693    0.649186   0.883191
# 71     0.832693    0.649186   0.883191
# 67     0.832032    0.648361   0.883507
# 65     0.829386    0.646352   0.889174
# 96     0.824096    0.639505   0.889802
# 101    0.798304    0.601226   0.867760
# 103    0.798304    0.601226   0.867760
# 99     0.797532    0.600600   0.868705
# 97     0.789265    0.592964   0.875631
#
#                                                                         v_hyp_para  \
# 1               {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 3              {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 5           {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 7          {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 33             {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 35            {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 37         {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 39        {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 17              {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 19             {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 21          {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 23         {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 49             {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 51            {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 53         {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 55        {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 82        {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 114      {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 56        {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 57             {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 24         {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 25              {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 125        {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 127       {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 91             {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 90        {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 124   {'C': 10000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 122      {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 123           {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 58       {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 59            {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 26        {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 27             {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 86    {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 118  {'C': 100000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 84     {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 93          {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 95         {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 116   {'C': 10000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 80         {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 126  {'C': 100000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 62   {'C': 100000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 61         {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 63        {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 28     {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 30    {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 60    {'C': 10000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 29          {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 31         {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 92     {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 89              {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 94    {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 88         {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 120       {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 121            {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 81              {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 112       {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 83             {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 85          {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 87         {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 22    {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 50       {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 48        {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 20     {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 113            {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 54   {'C': 100000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 52    {'C': 10000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 18        {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 16         {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 110  {'C': 100000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 108   {'C': 10000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 78    {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 111       {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 109        {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 102  {'C': 100000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 77          {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 79         {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 76     {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 13          {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 15         {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 100   {'C': 10000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 45         {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 47        {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 68     {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 70    {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 14    {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 12     {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 46   {'C': 100000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 44    {'C': 10000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 115           {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 75             {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 74        {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 106      {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 107           {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 117        {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 119       {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 10        {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 11             {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 43            {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 42       {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 9               {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 8          {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 40        {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 41             {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 72         {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 73              {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 104       {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 105            {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 66        {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 98       {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 4      {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 34       {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 38   {'C': 100000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 36    {'C': 10000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 6     {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 0          {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 32        {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 2         {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 64         {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 69          {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 71         {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 67             {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 65              {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 96        {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 101        {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 103       {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 99            {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 97             {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
#
#              scaler  v_SM_RU    normalized          scaled
# 1             False     True       X_train           False
# 3             False     True       X_train           False
# 5             False     True       X_train           False
# 7             False     True       X_train           False
# 33            False     True       X_train           False
# 35            False     True       X_train           False
# 37            False     True       X_train           False
# 39            False     True       X_train           False
# 17            False    False       X_train           False
# 19            False    False       X_train           False
# 21            False    False       X_train           False
# 23            False    False       X_train           False
# 49            False    False       X_train           False
# 51            False    False       X_train           False
# 53            False    False       X_train           False
# 55            False    False       X_train           False
# 82            False    False  X_train_Norm           False
# 114           False    False  X_train_Norm           False
# 56   MinMaxScaler()    False       X_train  MinMaxScaler()
# 57   MinMaxScaler()    False       X_train  MinMaxScaler()
# 24   MinMaxScaler()    False       X_train  MinMaxScaler()
# 25   MinMaxScaler()    False       X_train  MinMaxScaler()
# 125  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 127  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 91   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 90   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 124  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 122  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 123  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 58   MinMaxScaler()    False       X_train  MinMaxScaler()
# 59   MinMaxScaler()    False       X_train  MinMaxScaler()
# 26   MinMaxScaler()    False       X_train  MinMaxScaler()
# 27   MinMaxScaler()    False       X_train  MinMaxScaler()
# 86            False    False  X_train_Norm           False
# 118           False    False  X_train_Norm           False
# 84            False    False  X_train_Norm           False
# 93   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 95   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 116           False    False  X_train_Norm           False
# 80            False    False  X_train_Norm           False
# 126  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 62   MinMaxScaler()    False       X_train  MinMaxScaler()
# 61   MinMaxScaler()    False       X_train  MinMaxScaler()
# 63   MinMaxScaler()    False       X_train  MinMaxScaler()
# 28   MinMaxScaler()    False       X_train  MinMaxScaler()
# 30   MinMaxScaler()    False       X_train  MinMaxScaler()
# 60   MinMaxScaler()    False       X_train  MinMaxScaler()
# 29   MinMaxScaler()    False       X_train  MinMaxScaler()
# 31   MinMaxScaler()    False       X_train  MinMaxScaler()
# 92   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 89   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 94   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 88   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 120  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 121  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 81            False    False  X_train_Norm           False
# 112           False    False  X_train_Norm           False
# 83            False    False  X_train_Norm           False
# 85            False    False  X_train_Norm           False
# 87            False    False  X_train_Norm           False
# 22            False    False       X_train           False
# 50            False    False       X_train           False
# 48            False    False       X_train           False
# 20            False    False       X_train           False
# 113           False    False  X_train_Norm           False
# 54            False    False       X_train           False
# 52            False    False       X_train           False
# 18            False    False       X_train           False
# 16            False    False       X_train           False
# 110  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 108  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 78   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 111  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 109  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 102           False     True  X_train_Norm           False
# 77   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 79   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 76   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 13   MinMaxScaler()     True       X_train  MinMaxScaler()
# 15   MinMaxScaler()     True       X_train  MinMaxScaler()
# 100           False     True  X_train_Norm           False
# 45   MinMaxScaler()     True       X_train  MinMaxScaler()
# 47   MinMaxScaler()     True       X_train  MinMaxScaler()
# 68            False     True  X_train_Norm           False
# 70            False     True  X_train_Norm           False
# 14   MinMaxScaler()     True       X_train  MinMaxScaler()
# 12   MinMaxScaler()     True       X_train  MinMaxScaler()
# 46   MinMaxScaler()     True       X_train  MinMaxScaler()
# 44   MinMaxScaler()     True       X_train  MinMaxScaler()
# 115           False    False  X_train_Norm           False
# 75   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 74   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 106  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 107  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 117           False    False  X_train_Norm           False
# 119           False    False  X_train_Norm           False
# 10   MinMaxScaler()     True       X_train  MinMaxScaler()
# 11   MinMaxScaler()     True       X_train  MinMaxScaler()
# 43   MinMaxScaler()     True       X_train  MinMaxScaler()
# 42   MinMaxScaler()     True       X_train  MinMaxScaler()
# 9    MinMaxScaler()     True       X_train  MinMaxScaler()
# 8    MinMaxScaler()     True       X_train  MinMaxScaler()
# 40   MinMaxScaler()     True       X_train  MinMaxScaler()
# 41   MinMaxScaler()     True       X_train  MinMaxScaler()
# 72   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 73   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 104  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 105  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 66            False     True  X_train_Norm           False
# 98            False     True  X_train_Norm           False
# 4             False     True       X_train           False
# 34            False     True       X_train           False
# 38            False     True       X_train           False
# 36            False     True       X_train           False
# 6             False     True       X_train           False
# 0             False     True       X_train           False
# 32            False     True       X_train           False
# 2             False     True       X_train           False
# 64            False     True  X_train_Norm           False
# 69            False     True  X_train_Norm           False
# 71            False     True  X_train_Norm           False
# 67            False     True  X_train_Norm           False
# 65            False     True  X_train_Norm           False
# 96            False     True  X_train_Norm           False
# 101           False     True  X_train_Norm           False
# 103           False     True  X_train_Norm           False
# 99            False     True  X_train_Norm           False
# 97            False     True  X_train_Norm           False

# %%
#sort by highest prec
lr_tuned_grid_search_prec_sorted = lr_tuned_results_df.sort_values(\
    by=['v_avg_prec', 'v_avg_spec', 'v_avg_rec'], ascending=[False, False, False])

lr_tuned_grid_search_prec_sorted
# Out:
#      v_avg_spec  v_avg_prec  v_avg_rec  \
# 82     0.979831    0.933961   0.811720
# 56     0.976966    0.929386   0.861462
# 57     0.976966    0.929386   0.861462
# 24     0.976855    0.928979   0.860518
# 25     0.976745    0.928565   0.859885
# 114    0.978949    0.927953   0.772675
# 125    0.975533    0.927688   0.892632
# 127    0.975533    0.927672   0.892318
# 124    0.975092    0.927163   0.902389
# 91     0.975533    0.926914   0.882556
# 90     0.975422    0.926393   0.880040
# 58     0.974981    0.926172   0.891997
# 59     0.974981    0.926172   0.891997
# 86     0.974652    0.925956   0.901131
# 84     0.974651    0.925839   0.900501
# 26     0.974871    0.925788   0.891682
# 27     0.974871    0.925762   0.891053
# 126    0.974431    0.925757   0.907424
# 118    0.974652    0.925594   0.897036
# 122    0.975092    0.925356   0.878464
# 116    0.974541    0.925355   0.897666
# 123    0.975092    0.925330   0.878149
# 93     0.974651    0.925304   0.893578
# 95     0.974651    0.925304   0.893578
# 62     0.973990    0.924603   0.907430
# 28     0.973990    0.924595   0.907116
# 30     0.973990    0.924552   0.906486
# 61     0.973990    0.924408   0.903969
# 63     0.973990    0.924408   0.903969
# 60     0.973880    0.924300   0.907430
# 29     0.973880    0.924165   0.904283
# 31     0.973880    0.924165   0.904283
# 92     0.973549    0.923256   0.903963
# 94     0.973219    0.922625   0.908057
# 89     0.973548    0.918917   0.851071
# 88     0.972446    0.915585   0.847922
# 120    0.972006    0.914328   0.846346
# 121    0.972006    0.914328   0.846346
# 1      1.000000    0.900000   0.004410
# 3      1.000000    0.900000   0.004410
# 5      1.000000    0.900000   0.004410
# 7      1.000000    0.900000   0.004410
# 33     1.000000    0.900000   0.004410
# 35     1.000000    0.900000   0.004410
# 37     1.000000    0.900000   0.004410
# 39     1.000000    0.900000   0.004410
# 80     0.974540    0.896979   0.634752
# 110    0.953711    0.879067   0.957176
# 108    0.953490    0.878306   0.954971
# 78     0.953380    0.878297   0.956861
# 102    0.952388    0.876128   0.958122
# 76     0.952168    0.875528   0.956545
# 111    0.952499    0.875501   0.950561
# 109    0.952389    0.875261   0.950561
# 77     0.952168    0.875040   0.953082
# 79     0.952168    0.875040   0.953082
# 100    0.951727    0.874615   0.958121
# 13     0.951728    0.874510   0.957177
# 15     0.951728    0.874510   0.957177
# 45     0.951507    0.874023   0.957177
# 47     0.951507    0.874023   0.957177
# 68     0.951507    0.873864   0.955604
'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 102  {'C': 100000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 76     {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 111       {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 109        {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 77          {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 79         {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 100   {'C': 10000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 13          {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 15         {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 45         {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 47        {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 68     {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 70    {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 14    {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 12     {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 46   {'C': 100000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 22    {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 44    {'C': 10000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 50       {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 48        {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 75             {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 74        {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 20     {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 106      {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 107           {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 10        {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 11             {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 43            {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 42       {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 54   {'C': 100000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 52    {'C': 10000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 18        {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 16         {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 81              {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 9               {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 8          {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 40        {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 41             {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 73              {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 72         {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 112       {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 104       {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 105            {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 83             {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 85          {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 87         {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 66        {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 98       {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 115           {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 113            {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 117        {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 119       {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 4      {'C': 10000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 34       {'C': 10, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 38   {'C': 100000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 36    {'C': 10000, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 6     {'C': 100000, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 0          {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 32        {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 2         {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 64         {'C': 1, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# 69          {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 71         {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 67             {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 65              {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 96        {'C': 1, 'solver': 'liblinear', 'fit_intercept': False, 'penalty': 'l2'}
# 101        {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 103       {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 99            {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 97             {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 17              {'C': 1, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 19             {'C': 10, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 21          {'C': 10000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 23         {'C': 100000, 'solver': 'saga', 'fit_intercept': True, 'penalty': 'l2'}
# 49             {'C': 1, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 51            {'C': 10, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 53         {'C': 10000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
# 55        {'C': 100000, 'solver': 'saga', 'fit_intercept': False, 'penalty': 'l2'}
#
#              scaler  v_SM_RU    normalized          scaled
# 82            False    False  X_train_Norm           False
# 56   MinMaxScaler()    False       X_train  MinMaxScaler()
# 57   MinMaxScaler()    False       X_train  MinMaxScaler()
# 24   MinMaxScaler()    False       X_train  MinMaxScaler()
# 25   MinMaxScaler()    False       X_train  MinMaxScaler()
# 114           False    False  X_train_Norm           False
# 125  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 127  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 124  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 91   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 90   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 58   MinMaxScaler()    False       X_train  MinMaxScaler()
# 59   MinMaxScaler()    False       X_train  MinMaxScaler()
# 86            False    False  X_train_Norm           False
# 84            False    False  X_train_Norm           False
# 26   MinMaxScaler()    False       X_train  MinMaxScaler()
# 27   MinMaxScaler()    False       X_train  MinMaxScaler()
# 126  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 118           False    False  X_train_Norm           False
# 122  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 116           False    False  X_train_Norm           False
# 123  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 93   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 95   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 62   MinMaxScaler()    False       X_train  MinMaxScaler()
# 28   MinMaxScaler()    False       X_train  MinMaxScaler()
# 30   MinMaxScaler()    False       X_train  MinMaxScaler()
# 61   MinMaxScaler()    False       X_train  MinMaxScaler()
# 63   MinMaxScaler()    False       X_train  MinMaxScaler()
# 60   MinMaxScaler()    False       X_train  MinMaxScaler()
# 29   MinMaxScaler()    False       X_train  MinMaxScaler()
# 31   MinMaxScaler()    False       X_train  MinMaxScaler()
# 92   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 94   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 89   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 88   MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 120  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 121  MinMaxScaler()    False  X_train_Norm  MinMaxScaler()
# 1             False     True       X_train           False
# 3             False     True       X_train           False
# 5             False     True       X_train           False
# 7             False     True       X_train           False
# 33            False     True       X_train           False
# 35            False     True       X_train           False
# 37            False     True       X_train           False
# 39            False     True       X_train           False
# 80            False    False  X_train_Norm           False
# 110  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 108  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 78   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 102           False     True  X_train_Norm           False
# 76   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 111  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 109  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 77   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 79   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 100           False     True  X_train_Norm           False
# 13   MinMaxScaler()     True       X_train  MinMaxScaler()
# 15   MinMaxScaler()     True       X_train  MinMaxScaler()
# 45   MinMaxScaler()     True       X_train  MinMaxScaler()
# 47   MinMaxScaler()     True       X_train  MinMaxScaler()
# 68            False     True  X_train_Norm           False
# 70            False     True  X_train_Norm           False
# 14   MinMaxScaler()     True       X_train  MinMaxScaler()
# 12   MinMaxScaler()     True       X_train  MinMaxScaler()
# 46   MinMaxScaler()     True       X_train  MinMaxScaler()
# 22            False    False       X_train           False
# 44   MinMaxScaler()     True       X_train  MinMaxScaler()
# 50            False    False       X_train           False
# 48            False    False       X_train           False
# 75   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 74   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 20            False    False       X_train           False
# 106  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 107  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 10   MinMaxScaler()     True       X_train  MinMaxScaler()
# 11   MinMaxScaler()     True       X_train  MinMaxScaler()
# 43   MinMaxScaler()     True       X_train  MinMaxScaler()
# 42   MinMaxScaler()     True       X_train  MinMaxScaler()
# 54            False    False       X_train           False
# 52            False    False       X_train           False
# 18            False    False       X_train           False
# 16            False    False       X_train           False
# 81            False    False  X_train_Norm           False
# 9    MinMaxScaler()     True       X_train  MinMaxScaler()
# 8    MinMaxScaler()     True       X_train  MinMaxScaler()
# 40   MinMaxScaler()     True       X_train  MinMaxScaler()
# 41   MinMaxScaler()     True       X_train  MinMaxScaler()
# 73   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 72   MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 112           False    False  X_train_Norm           False
# 104  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 105  MinMaxScaler()     True  X_train_Norm  MinMaxScaler()
# 83            False    False  X_train_Norm           False
# 85            False    False  X_train_Norm           False
# 87            False    False  X_train_Norm           False
# 66            False     True  X_train_Norm           False
# 98            False     True  X_train_Norm           False
# 115           False    False  X_train_Norm           False
# 113           False    False  X_train_Norm           False
# 117           False    False  X_train_Norm           False
# 119           False    False  X_train_Norm           False
# 4             False     True       X_train           False
# 34            False     True       X_train           False
# 38            False     True       X_train           False
# 36            False     True       X_train           False
# 6             False     True       X_train           False
# 0             False     True       X_train           False
# 32            False     True       X_train           False
# 2             False     True       X_train           False
# 64            False     True  X_train_Norm           False
# 69            False     True  X_train_Norm           False
# 71            False     True  X_train_Norm           False
# 67            False     True  X_train_Norm           False
# 65            False     True  X_train_Norm           False
# 96            False     True  X_train_Norm           False
# 101           False     True  X_train_Norm           False
# 103           False     True  X_train_Norm           False
# 99            False     True  X_train_Norm           False
# 97            False     True  X_train_Norm           False
# 17            False    False       X_train           False
# 19            False    False       X_train           False
# 21            False    False       X_train           False
# 23            False    False       X_train           False
# 49            False    False       X_train           False
# 51            False    False       X_train           False
# 53            False    False       X_train           False
# 55            False    False       X_train           False

# %% [markdown]
# ## diplay the results of the optimized logistic regression model

# %%
model_kwargs= {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2' }
print(model_kwargs)
#instantiate the class
Tuned_LR_Model_Results= ModelWithCV(model_instantiator= LogisticRegression,
                  model_name= 'Tuned_LR_Model',
                  X= X_train_Norm,
                  y= y_train,
                  scaler= False,
                  smote_and_rand_und= False,
                  model_kwargs= model_kwargs)

Tuned_LR_Model_Results.plot_avg_conf_matrix()

print('results for DT baseline (previous best model):')
DT_Baseline_Results.print_cv_summary()
print()
print('results for Tuned LR:')
Tuned_LR_Model_Results.print_cv_summary()
# Out:
# {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'}
# results for DT baseline (previous best model):
# ###TRAIN###
# CV results for DT_Base_Model model:Average specificity: 1.00000
# Average precision: 1.00000
# Average recall: 1.00000
# ###VAL###
# CV results for DT_Base_Model model:Average specificity: 0.96352
# Average precision: 0.89575
# Average recall: 0.89389
#
# results for Tuned LR:
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.98004
# Average precision: 0.93440
# Average recall: 0.81224
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.97983
# Average precision: 0.93396
# Average recall: 0.81172
# (0.9798307583212313,
#  0.9339614675372335,
#  0.8117195405035416,
#  {'C': 10, 'solver': 'liblinear', 'fit_intercept': True, 'penalty': 'l2'},
#  False,
#  False)

# %% [markdown]
# ## tune decision tree via grid search

# %% [markdown]
# This search scale has been narrowed down to parameters previously discovered to be effective, while still demonstrating the effectiveness and utility of the code. This is because previous wider searches have proven to be too computationally expensive for my current computer to handle, and cause the notebook to significantly slow down and or crash. One potential way to mitigate this would be to split up the grid search to tune for one parameter at a time.

# %%
dt_metric_tracker= []
dt_data_and_scaler= []

data_sets= [X_train]
#computer couldn't handle iterating past the max depth of 1, max output was 5,370 iterations
#truncate depth range from 1-33 to 1-4
max_depths= [2,3,4,5]
#change 10 steps down to 5
min_samples_splits = [0.05, 0.1, 0.15]
criterions = ['gini']
#change 10 steps down to 5
min_samples_leafs = [.1225, .1325, .1425]
max_feature_num = [2, 3, 4, 5]
smote= [True]
scaler= [False]

for data, data_name in zip(data_sets, ["X_train", "X_train_Norm"]):
    for depth in max_depths:
        for sm in smote:
            for sc in scaler:        
                for fit in int_fit:
                    for samp_split in min_samples_splits:
                        for solver in solvers:
                            for crit in criterions:
                                for samp_leafs in min_samples_leafs:
                                    for num_feat in max_feature_num:
                                        model_kwargs= {'max_depth': depth, 'min_samples_split': samp_split, 
                                                        'criterion': crit, 'min_samples_leaf': samp_leafs, 
                                                        'max_features': num_feat}
                                        print(model_kwargs)
                                        #instantiate the class
                                        temp= ModelWithCV(model_instantiator= DecisionTreeClassifier,
                                                                            model_name= 'Tuned_DT_Model',
                                                                            X= data,
                                                                            y= y_train,
                                                                            scaler= sc,
                                                                            smote_and_rand_und= sm,
                                                                            model_kwargs= model_kwargs
                                                                           )
                                        
                                        dt_metric_tracker.append(temp.print_cv_summary())
                                        dt_data_and_scaler.append((data_name, sc))
                                        
                                        print()
                                        print('#### NEXT ITERATION###')
# Out:
# {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 2}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.89003
# Average precision: 0.89234
# Average recall: 0.91087
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.88956
# Average precision: 0.73643
# Average recall: 0.88066
#
# #### NEXT ITERATION###
# {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 3}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.97821
# Average precision: 0.97489
# Average recall: 0.84579
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.97851
# Average precision: 0.93219
# Average recall: 0.84100
#
# #### NEXT ITERATION###
# {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98119
# Average precision: 0.97833
# Average recall: 0.84892
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98137
# Average precision: 0.94095
# Average recall: 0.84289
#
# #### NEXT ITERATION###
# {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 5}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.79301
# Average precision: 0.82581
# Average recall: 0.98083
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.79180
# Average precision: 0.62231
# Average recall: 0.97418
#
# #### NEXT ITERATION###
# {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 2}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.89373
# Average precision: 0.89390
# Average recall: 0.89475
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.89309
# Average precision: 0.73832
# Average recall: 0.86114
#
# #### NEXT ITERATION###
# {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 3}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98108
# Average precision: 0.97768
# Average recall: 0.82869
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98104
# Average precision: 0.93870
# Average recall: 0.82558
#
# #### NEXT ITERATION###
# {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98408
# Average precision: 0.98122
# Average recall: 0.83150
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98391
# Average precision: 0.
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98104
# Average precision: 0.93870
# Average recall: 0.82558
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98408
# Average precision: 0.98122
# Average recall: 0.83150
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98391
# Average precision: 0.94762
# Average recall: 0.82526
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 5}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.79301
# Average precision: 0.82581
# Average recall: 0.98083
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.79180
# Average precision: 0.62231
# Average recall: 0.97418
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 2}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.89742
# Average precision: 0.89549
# Average recall: 0.87833
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.89673
# Average precision: 0.74059
# Average recall: 0.84130
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98381
# Average precision: 0.98044
# Average recall: 0.81137
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98391
# Average precision: 0.94643
# Average recall: 0.80700
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98668
# Average precision: 0.98390
# Average recall: 0.81428
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98677
# Average precision: 0.95563
# Average recall: 0.80668
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 5}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.79301
# Average precision: 0.82581
# Average recall: 0.98083
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.79180
# Average precision: 0.62231
# Average recall: 0.97418
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 2}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.89003
# Average precision: 0.89234
# Average recall: 0.91087
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.88956
# Average precision: 0.73643
# Average recall: 0.88066
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 3}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.97821
# Average precision: 0.97489
# Average recall: 0.84579
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.97851
# Average precision: 0.93219
# Average recall: 0.84100
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98119
# Average precision: 0.97833
# Average recall: 0.84892
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98137
# Average precision: 0.94095
# Average recall: 0.84289
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 5}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.79301
# Average precision: 0.82581
# Average recall: 0.98083
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.79180
# Average precision: 0.62231
# Average recall: 0.97418
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 2}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.89373
# Average precision: 0.89390
# Average recall: 0.89475
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.89309
# Average precision: 0.73832
# Average recall: 0.86114
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 3}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98108
# Average precision: 0.97768
# Average recall: 0.82869
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98104
# Average precision: 0.93870
# Average recall: 0.82558
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98408
# Average precision: 0.98122
# Average recall: 0.83150
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98391
# Average precision: 0.94762
# Average recall: 0.82526
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 5}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.79301
# Average precision: 0.82581
# Average recall: 0.98083
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.79180
# Average precision: 0.62231
# Average recall: 0.97418
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 2}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.89742
# Average precision: 0.89549
# Average recall: 0.87833
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.89673
# Average precision: 0.74059
# Average recall: 0.84130
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98381
# Average precision: 0.98044
# Average recall: 0.81137
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98391
# Average precision: 0.94643
# Average recall: 0.80700
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98668
# Average precision: 0.98390
# Average recall: 0.81428
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98677
# Average precision: 0.95563
# Average recall: 0.80668
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 5}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.79301
# Average precision: 0.82581
# Average recall: 0.98083
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.79180
# Average precision: 0.62231
# Average recall: 0.97418
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 2}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.89003
# Average precision: 0.89234
# Average recall: 0.91087
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.88956
# Average precision: 0.73643
# Average recall: 0.88066
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 3}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.97821
# Average precision: 0.97489
# Average recall: 0.84579
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.97851
# Average precision: 0.93219
# Average recall: 0.84100
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98119
# Average precision: 0.97833
# Average recall: 0.84892
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98137
# Average precision: 0.94095
# Average recall: 0.84289
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 5}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.79301
# Average precision: 0.82581
# Average recall: 0.98083
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.79180
# Average precision: 0.62231
# Average recall: 0.97418
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 2}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.89373
# Average precision: 0.89390
# Average recall: 0.89475
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.89309
# Average precision: 0.73832
# Average recall: 0.86114
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 3}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98108
# Average precision: 0.97768
# Average recall: 0.82869
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98104
# Average precision: 0.93870
# Average recall: 0.82558
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98408
# Average precision: 0.98122
# Average recall: 0.83150
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98391
# Average precision: 0.94762
# Average recall: 0.82526
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 5}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.79301
# Average precision: 0.82581
# Average recall: 0.98083
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.79180
# Average precision: 0.62231
# Average recall: 0.97418
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 2}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.89742
# Average precision: 0.89549
# Average recall: 0.87833
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.89673
# Average precision: 0.74059
# Average recall: 0.84130
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98381
# Average precision: 0.98044
# Average recall: 0.81137
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98391
# Average precision: 0.94643
# Average recall: 0.80700
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.98668
# Average precision: 0.98390
# Average recall: 0.81428
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.98677
# Average precision: 0.95563
# Average recall: 0.80668
#
# #### NEXT ITERATION###
# {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 5}
# SMOTEing and Randomly Undersampling
# ###TRAIN###
# CV results for Tuned_DT_Model model:Average specificity: 0.79301
# Average precision: 0.82581
# Average recall: 0.98083
# ###VAL###
# CV results for Tuned_DT_Model model:Average specificity: 0.79180
# Average precision: 0.62231
# Average recall: 0.97418
#
# #### NEXT ITERATION###

# %%
dt_metrics_df= pd.DataFrame(dt_metric_tracker)

dt_data_scaler_df= pd.DataFrame(dt_data_and_scaler)

dt_tuned_results_df = pd.merge(dt_metrics_df, dt_data_scaler_df, left_index=True, right_index=True)

print(len(dt_tuned_results_df))

# 411    0.791801    0.622309   0.974177
# 415    0.791801    0.622309   0.974177
# 419    0.791801    0.622309   0.974177
# 423    0.791801    0.622309   0.974177
# 427    0.791801    0.622309   0.974177
# 431    0.791801    0.622309   0.974177
# 435    0.791801    0.622309   0.974177
# 439    0.791801    0.622309   0.974177
# 443    0.791801    0.622309   0.974177
# 447    0.791801    0.622309   0.974177
# 451    0.791801    0.622309   0.974177
# 455    0.791801    0.622309   0.974177
# 459    0.791801    0.622309   0.974177
# 463    0.791801    0.622309   0.974177
# 467    0.791801    0.622309   0.974177
# 471    0.791801    0.622309   0.974177
# 475    0.791801    0.622309   0.974177
# 479    0.791801    0.622309   0.974177
# 483    0.791801    0.622309   0.974177
# 487    0.791801    0.622309   0.974177
# 491    0.791801    0.622309   0.974177
# 495    0.791801    0.622309   0.974177
# 499    0.791801    0.622309   0.974177
# 503    0.791801    0.622309   0.974177
# 507    0.791801    0.622309   0.974177
# 511    0.791801    0.622309   0.974177
# 515    0.791801    0.622309   0.974177
# 519    0.791801    0.622309   0.974177
# 523    0.791801    0.622309   0.974177
# 527    0.791801    0.622309   0.974177
# 531    0.791801    0.622309   0.974177
# 535    0.791801    0.622309   0.974177
# 539    0.791801    0.622309   0.974177
# 543    0.791801    0.622309   0.974177
# 547    0.791801    0.622309   0.974177
# 551    0.791801    0.622309   0.974177
# 555    0.791801    0.622309   0.974177
# 559    0.791801    0.622309   0.974177
# 563    0.791801    0.622309   0.974177
# 567    0.791801    0.622309   0.974177
# 571    0.791801    0.622309   0.974177
# 575    0.791801    0.622309   0.974177
#
#                                                                                                           v_hyp_para  \
# 10   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 22   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 34    {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 46    {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 58   {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 70   {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 82   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 94   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 106   {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 118   {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 130  {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 142  {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 154  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 166  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 178   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 190   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 202  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 214  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 226  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 238  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 250   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 262   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 274  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 286  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 298  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 310  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 322   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 334   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 346  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 358  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 370  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 382  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 394   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 406   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 418  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 430  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 442  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 454  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 466   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 478   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 490  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 502  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 514  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 526  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 538   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 550   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 562  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 574  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 4}
# 6    {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 18   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 30    {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 42    {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 54   {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 66   {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 78   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 90   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 102   {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 114   {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 126  {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 138  {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 150  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 162  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 174   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 186   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 198  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 210  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 222  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 234  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 246   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 258   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 270  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 282  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 294  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 306  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 318   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 330   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 342  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 354  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 366  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 378  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 390   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 402   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 414  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 426  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 438  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 450  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 462   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 474   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 486  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 498  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 510  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 522  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 534   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 546   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 558  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 570  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# 9    {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 21   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 33    {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 45    {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 57   {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 69   {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 81   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 93   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 105   {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 117   {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 129  {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 141  {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 153  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 165  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 177   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 189   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 201  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 213  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 225  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 237  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 249   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 261   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 273  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 285  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 297  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 309  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 321   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 333   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 345  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 357  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 369  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 381  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 393   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 405   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 417  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 429  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 441  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 453  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 465   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 477   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 489  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 501  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 513  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 525  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 537   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 549   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 561  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 573  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1425, 'max_features': 3}
# 2    {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 14   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 26    {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 38    {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 50   {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 62   {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 74   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 86   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 98    {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 110   {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 122  {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 134  {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 146  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 158  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 170   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 182   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 194  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 206  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 218  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 230  {'max_depth': 3, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 242   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 254   {'max_depth': 3, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 266  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 278  {'max_depth': 3, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 290  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 302  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 314   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 326   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 338  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 350  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 362  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 374  {'max_depth': 4, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 386   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 398   {'max_depth': 4, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 410  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 422  {'max_depth': 4, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 434  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 446  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 458   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 470   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 482  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 494  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 506  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 518  {'max_depth': 5, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 530   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 542   {'max_depth': 5, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 554  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 566  {'max_depth': 5, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1225, 'max_features': 4}
# 5    {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 3}
# 17   {'max_depth': 2, 'min_samples_split': 0.05, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 3}
# 29    {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 3}
# 41    {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 3}
# 53   {'max_depth': 2, 'min_samples_split': 0.15, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 3}
# ...
# 41    False     True    X_train   False
# 53    False     True    X_train   False
# 65    False     True    X_train   False
# 77    False     True    X_train   False
# 89    False     True    X_train   False
# 101   False     True    X_train   False
# 113   False     True    X_train   False
# 125   False     True    X_train   False
# 137   False     True    X_train   False
# 149   False     True    X_train   False
# 161   False     True    X_train   False
# 173   False     True    X_train   False
# 185   False     True    X_train   False
# 197   False     True    X_train   False
# 209   False     True    X_train   False
# 221   False     True    X_train   False
# 233   False     True    X_train   False
# 245   False     True    X_train   False
# 257   False     True    X_train   False
# 269   False     True    X_train   False
# 281   False     True    X_train   False
# 293   False     True    X_train   False
# 305   False     True    X_train   False
# 317   False     True    X_train   False
# 329   False     True    X_train   False
# 341   False     True    X_train   False
# 353   False     True    X_train   False
# 365   False     True    X_train   False
# 377   False     True    X_train   False
# 389   False     True    X_train   False
# 401   False     True    X_train   False
# 413   False     True    X_train   False
# 425   False     True    X_train   False
# 437   False     True    X_train   False
# 449   False     True    X_train   False
# 461   False     True    X_train   False
# 473   False     True    X_train   False
# 485   False     True    X_train   False
# 497   False     True    X_train   False
# 509   False     True    X_train   False
# 521   False     True    X_train   False
# 533   False     True    X_train   False
# 545   False     True    X_train   False
# 557   False     True    X_train   False
# 569   False     True    X_train   False
# 1     False     True    X_train   False
# 13    False     True    X_train   False
# 25    False     True    X_train   False
# 37    False     True    X_train   False
# 49    False     True    X_train   False
# 61    False     True    X_train   False
# 73    False     True    X_train   False
# 85    False     True    X_train   False
# 97    False     True    X_train   False
# 109   False     True    X_train   False
# 121   False     True    X_train   False
# 133   False     True    X_train   False
# 145   False     True    X_train   False
# 157   False     True    X_train   False
# 169   False     True    X_train   False
# 181   False     True    X_train   False
# 193   False     True    X_train   False
# 205   False     True    X_train   False
# 217   False     True    X_train   False
# 229   False     True    X_train   False
# 241   False     True    X_train   False
# 253   False     True    X_train   False
# 265   False     True    X_train   False
# 277   False     True    X_train   False
# 289   False     True    X_train   False
# 301   False     True    X_train   False
# 313   False     True    X_train   False
# 325   False     True    X_train   False
# 337   False     True    X_train   False
# 349   False     True    X_train   False
# 361   False     True    X_train   False
# 373   False     True    X_train   False
# 385   False     True    X_train   False
# 397   False     True    X_train   False
# 409   False     True    X_train   False
# 421   False     True    X_train   False
# 433   False     True    X_train   False
# 445   False     True    X_train   False
# 457   False     True    X_train   False
# 469   False     True    X_train   False
# 481   False     True    X_train   False
# 493   False     True    X_train   False
# 505   False     True    X_train   False
# 517   False     True    X_train   False
# 529   False     True    X_train   False
# 541   False     True    X_train   False
# 553   False     True    X_train   False
# 565   False     True    X_train   False
# 8     False     True    X_train   False
# 20    False     True    X_train   False
# 32    False     True    X_train   False
# 44    False     True    X_train   False
# 56    False     True    X_train   False
# 68    False     True    X_train   False
# 80    False     True    X_train   False
# 92    False     True    X_train   False
# 104   False     True    X_train   False
# 116   False     True    X_train   False
# 128   False     True    X_train   False
# 140   False     True    X_train   False
# 152   False     True    X_train   False
# 164   False     True    X_train   False
# 176   False     True    X_train   False
# 188   False     True    X_train   False
# 200   False     True    X_train   False
# 212   False     True    X_train   False
# 224   False     True    X_train   False
# 236   False     True    X_train   False
# 248   False     True    X_train   False
# 260   False     True    X_train   False
# 272   False     True    X_train   False
# 284   False     True    X_train   False
# 296   False     True    X_train   False
# 308   False     True    X_train   False
# 320   False     True    X_train   False
# 332   False     True    X_train   False
# 344   False     True    X_train   False
# 356   False     True    X_train   False
# 368   False     True    X_train   False
# 380   False     True    X_train   False
# 392   False     True    X_train   False
# 404   False     True    X_train   False
# 416   False     True    X_train   False
# 428   False     True    X_train   False
# 440   False     True    X_train   False
# 452   False     True    X_train   False
# 464   False     True    X_train   False
# 476   False     True    X_train   False
# 488   False     True    X_train   False
# 500   False     True    X_train   False
# 512   False     True    X_train   False
# 524   False     True    X_train   False
# 536   False     True    X_train   False
# 548   False     True    X_train   False
# 560   False     True    X_train   False
# 572   False     True    X_train   False
# 4     False     True    X_train   False
# 16    False     True    X_train   False
# 28    False     True    X_train   False
# 40    False     True    X_train   False
# 52    False     True    X_train   False
# 64    False     True    X_train   False
# 76    False     True    X_train   False
# 88    False     True    X_train   False
# 100   False     True    X_train   False
# 112   False     True    X_train   False
# 124   False     True    X_train   False
# 136   False     True    X_train   False
# 148   False     True    X_train   False
# 160   False     True    X_train   False
# 172   False     True    X_train   False
# 184   False     True    X_train   False
# 196   False     True    X_train   False
# 208   False     True    X_train   False
# 220   False     True    X_train   False
# 232   False     True    X_train   False
# 244   False     True    X_train   False
# 256   False     True    X_train   False
# 268   False     True    X_train   False
# 280   False     True    X_train   False
# 292   False     True    X_train   False
# 304   False     True    X_train   False
# 316   False     True    X_train   False
# 328   False     True    X_train   False
# 340   False     True    X_train   False
# 352   False     True    X_train   False
# 364   False     True    X_train   False
# 376   False     True    X_train   False
# 388   False     True    X_train   False
# 400   False     True    X_train   False
# 412   False     True    X_train   False
# 424   False     True    X_train   False
# 436   False     True    X_train   False
# 448   False     True    X_train   False
# 460   False     True    X_train   False
# 472   False     True    X_train   False
# 484   False     True    X_train   False
# 496   False     True    X_train   False
# 508   False     True    X_train   False
# 520   False     True    X_train   False
# 532   False     True    X_train   False
# 544   False     True    X_train   False
# 556   False     True    X_train   False
# 568   False     True    X_train   False
# 0     False     True    X_train   False
# 12    False     True    X_train   False
# 24    False     True    X_train   False
# 36    False     True    X_train   False
# 48    False     True    X_train   False
# 60    False     True    X_train   False
# 72    False     True    X_train   False
# 84    False     True    X_train   False
# 96    False     True    X_train   False
# 108   False     True    X_train   False
# 120   False     True    X_train   False
# 132   False     True    X_train   False
# 144   False     True    X_train   False
# 156   False     True    X_train   False
# 168   False     True    X_train   False
# 180   False     True    X_train   False
# 192   False     True    X_train   False
# 204   False     True    X_train   False
# 216   False     True    X_train   False
# 228   False     True    X_train   False
# 240   False     True    X_train   False
# 252   False     True    X_train   False
# 264   False     True    X_train   False
# 276   False     True    X_train   False
# 288   False     True    X_train   False
# 300   False     True    X_train   False
# 312   False     True    X_train   False
# 324   False     True    X_train   False
# 336   False     True    X_train   False
# 348   False     True    X_train   False
# 360   False     True    X_train   False
# 372   False     True    X_train   False
# 384   False     True    X_train   False
# 396   False     True    X_train   False
# 408   False     True    X_train   False
# 420   False     True    X_train   False
# 432   False     True    X_train   False
# 444   False     True    X_train   False
# 456   False     True    X_train   False
# 468   False     True    X_train   False
# 480   False     True    X_train   False
# 492   False     True    X_train   False
# 504   False     True    X_train   False
# 516   False     True    X_train   False
# 528   False     True    X_train   False
# 540   False     True    X_train   False
# 552   False     True    X_train   False
# 564   False     True    X_train   False
# 3     False     True    X_train   False
# 7     False     True    X_train   False
# 11    False     True    X_train   False
# 15    False     True    X_train   False
# 19    False     True    X_train   False
# 23    False     True    X_train   False
# 27    False     True    X_train   False
# 31    False     True    X_train   False
# 35    False     True    X_train   False
# 39    False     True    X_train   False
# 43    False     True    X_train   False
# 47    False     True    X_train   False
# 51    False     True    X_train   False
# 55    False     True    X_train   False
# 59    False     True    X_train   False
# 63    False     True    X_train   False
# 67    False     True    X_train   False
# 71    False     True    X_train   False
# 75    False     True    X_train   False
# 79    False     True    X_train   False
# 83    False     True    X_train   False
# 87    False     True    X_train   False
# 91    False     True    X_train   False
# 95    False     True    X_train   False
# 99    False     True    X_train   False
# 103   False     True    X_train   False
# 107   False     True    X_train   False
# 111   False     True    X_train   False
# 115   False     True    X_train   False
# 119   False     True    X_train   False
# 123   False     True    X_train   False
# 127   False     True    X_train   False
# 131   False     True    X_train   False
# 135   False     True    X_train   False
# 139   False     True    X_train   False
# 143   False     True    X_train   False
# 147   False     True    X_train   False
# 151   False     True    X_train   False
# 155   False     True    X_train   False
# 159   False     True    X_train   False
# 163   False     True    X_train   False
# 167   False     True    X_train   False
# 171   False     True    X_train   False
# 175   False     True    X_train   False
# 179   False     True    X_train   False
# 183   False     True    X_train   False
# 187   False     True    X_train   False
# 191   False     True    X_train   False
# 195   False     True    X_train   False
# 199   False     True    X_train   False
# 203   False     True    X_train   False
# 207   False     True    X_train   False
# 211   False     True    X_train   False
# 215   False     True    X_train   False
# 219   False     True    X_train   False
# 223   False     True    X_train   False
# 227   False     True    X_train   False
# 231   False     True    X_train   False
# 235   False     True    X_train   False
# 239   False     True    X_train   False
# 243   False     True    X_train   False
# 247   False     True    X_train   False
# 251   False     True    X_train   False
# 255   False     True    X_train   False
# 259   False     True    X_train   False
# 263   False     True    X_train   False
# 267   False     True    X_train   False
# 271   False     True    X_train   False
# 275   False     True    X_train   False
# 279   False     True    X_train   False
# 283   False     True    X_train   False
# 287   False     True    X_train   False
# 291   False     True    X_train   False
# 295   False     True    X_train   False
# 299   False     True    X_train   False
# 303   False     True    X_train   False
# 307   False     True    X_train   False
# 311   False     True    X_train   False
# 315   False     True    X_train   False
# 319   False     True    X_train   False
# 323   False     True    X_train   False
# 327   False     True    X_train   False
# 331   False     True    X_train   False
# 335   False     True    X_train   False
# 339   False     True    X_train   False
# 343   False     True    X_train   False
# 347   False     True    X_train   False
# 351   False     True    X_train   False
# 355   False     True    X_train   False
# 359   False     True    X_train   False
# 363   False     True    X_train   False
# 367   False     True    X_train   False
# 371   False     True    X_train   False
# 375   False     True    X_train   False
# 379   False     True    X_train   False
# 383   False     True    X_train   False
# 387   False     True    X_train   False
# 391   False     True    X_train   False
# 395   False     True    X_train   False
# 399   False     True    X_train   False
# 403   False     True    X_train   False
# 407   False     True    X_train   False
# 411   False     True    X_train   False
# 415   False     True    X_train   False
# 419   False     True    X_train   False
# 423   False     True    X_train   False
# 427   False     True    X_train   False
# 431   False     True    X_train   False
# 435   False     True    X_train   False
# 439   False     True    X_train   False
# 443   False     True    X_train   False
# 447   False     True    X_train   False
# 451   False     True    X_train   False
# 455   False     True    X_train   False
# 459   False     True    X_train   False
# 463   False     True    X_train   False
# 467   False     True    X_train   False
# 471   False     True    X_train   False
# 475   False     True    X_train   False
# 479   False     True    X_train   False
# 483   False     True    X_train   False
# 487   False     True    X_train   False
# 491   False     True    X_train   False
# 495   False     True    X_train   False
# 499   False     True    X_train   False
# 503   False     True    X_train   False
# 507   False     True    X_train   False
# 511   False     True    X_train   False
# 515   False     True    X_train   False
# 519   False     True    X_train   False
# 523   False     True    X_train   False
# 527   False     True    X_train   False
# 531   False     True    X_train   False
# 535   False     True    X_train   False
# 539   False     True    X_train   False
# 543   False     True    X_train   False
# 547   False     True    X_train   False
# 551   False     True    X_train   False
# 555   False     True    X_train   False
# 559   False     True    X_train   False
# 563   False     True    X_train   False
# 567   False     True    X_train   False
# 571   False     True    X_train   False
# 575   False     True    X_train   False

# %% [markdown]
# ## display the results of the tuned decision tree model

# %%
model_kwargs= {'max_depth': 2, 'min_samples_split': 0.1,
               'criterion': 'gini', 'min_samples_leaf': 0.1325, 
               'max_features': 4}

print(model_kwargs)
#instantiate the class
Tuned_DT_Model_Results= ModelWithCV(model_instantiator= DecisionTreeClassifier,
                  model_name= 'Tuned_LR_Model',
                  X= X_train_Norm,
                  y= y_train,
                  scaler= False,
                  smote_and_rand_und= True,
                  model_kwargs= model_kwargs)

Tuned_DT_Model_Results.plot_avg_conf_matrix()

print('results for DT baseline:')
DT_Baseline_Results.print_cv_summary()
print()
print('results for Tuned LR(previous best model):')
Tuned_LR_Model_Results.print_cv_summary()
print()
print('results for Tuned DT:')
Tuned_DT_Model_Results.print_cv_summary()
# Out:
# {'max_depth': 2, 'min_samples_split': 0.1, 'criterion': 'gini', 'min_samples_leaf': 0.1325, 'max_features': 4}
# SMOTEing and Randomly Undersampling
# results for DT baseline:
# ###TRAIN###
# CV results for DT_Base_Model model:Average specificity: 1.00000
# Average precision: 1.00000
# Average recall: 1.00000
# ###VAL###
# CV results for DT_Base_Model model:Average specificity: 0.96352
# Average precision: 0.89575
# Average recall: 0.89389
#
# results for Tuned LR(previous best model):
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.98004
# Average precision: 0.93440
# Average recall: 0.81224
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.97983
# Average precision: 0.93396
# Average recall: 0.81172
#
# results for Tuned DT:
# ###TRAIN###
# CV results for Tuned_LR_Model model:Average specificity: 0.98381
# Average precision: 0.98086
# Average recall: 0.82945
# ###VAL###
# CV results for Tuned_LR_Model model:Average specificity: 0.98347
# Average precision: 0.94633
# Average recall: 0.82525
# (0.9834677908970368,
#  0.9463345335106264,
#  0.8252544491399322,
#  {'max_depth': 2,
#   'min_samples_split': 0.1,
#   'criterion': 'gini',
#   'min_samples_leaf': 0.1325,
#   'max_features': 4},
#  False,
#  True)

# %% [markdown]
# ## Run the final model on the test data

# %%
#works
class Model_with_final():
    def __init__(self, model_instantiator, model_name, X_tr, y_tr, X_te, y_te, 
                 smote_and_rand_und= False, model_kwargs = {}):
        self.model_instatiator = model_instantiator
        self.model = None
        self.name = model_name
        self.model_kwargs = model_kwargs
        self.X_train = X_tr
        self.y_train = y_tr
        self.X_test = X_te
        self.y_test = y_te
        self.smote_and_rand_und= smote_and_rand_und
        self.model_kwargs = model_kwargs
        self.final_results = None
        self.final_accuracy = None
        self.final_specificity = None
        self.final_precision = None
        self.final_recall = None
        self.final_conf_matrix = None
        
        self.train_and_evaluate()

    def train_and_evaluate(self):
        
        self.model = self.model_instatiator(random_state= 24, **self.model_kwargs)
        
        if self.smote_and_rand_und:
            print('SMOTEing and Randomly Undersampling')
            smote = SMOTE(sampling_strategy='auto', random_state=24)  
            undersample = RandomUnderSampler(sampling_strategy='auto', random_state=24)
            pipeline = Pipeline(steps=[('smote', smote), ('undersample', undersample)])
        
            X_train, y_train = pipeline.fit_resample(self.X_train, self.y_train)
               
        self.model.fit(X_train, y_train)
        y_pred = self.model.predict(self.X_test)
        self.final_accuracy = accuracy_score(self.y_test, y_pred)
        self.final_conf_matrix = confusion_matrix(self.y_test, y_pred)
        TN, FP, FN, TP = self.final_conf_matrix.ravel()
        self.final_specificity = TN / (TN + FP)
        self.final_precision = precision_score(self.y_test, y_pred)
        self.final_recall = recall_score(self.y_test, y_pred)
        self.final_results = {'Accuracy': self.final_accuracy,
            'Specificity': self.final_specificity,
            'Precision': self.final_precision,
            'Recall': self.final_recall}

    def print_final_summary(self):
        print(f"Final results for {self.name} model on X_test:")
        print(f"Accuracy: {self.final_accuracy:.5f}")
        print(f"Specificity: {self.final_specificity:.5f}")
        print(f"Precision: {self.final_precision:.5f}")
        print(f"Recall: {self.final_recall:.5f}")

    def plot_conf_matrix(self):
        if self.final_conf_matrix is not None:
            disp = ConfusionMatrixDisplay(confusion_matrix=self.final_conf_matrix)
            disp.plot(cmap=plt.cm.Blues, values_format='.2f')
            plt.title(f"Confusion Matrix for {self.name} on X_test")
            plt.show()

# %%
model_kwargs= {'max_depth': 2, 'min_samples_split': 0.1,
               'criterion': 'gini', 'min_samples_leaf': 0.1325, 
               'max_features': 4}

#instantiate the class
Final_Model_Results= Model_with_final(model_instantiator= DecisionTreeClassifier,
                                    model_name= 'Final_Model: Smoted/Randomly Undersampled and Tuned Decision Tree model',
                                    X_tr = X_train,
                                    y_tr = y_train,
                                     X_te = X_test,
                                     y_te = y_test,
                                     smote_and_rand_und= True,
                                     model_kwargs= model_kwargs)

Final_Model_Results.plot_conf_matrix()

Final_Model_Results.print_final_summary()
# Out:
# SMOTEing and Randomly Undersampling
# Final results for Final_Model: Smoted/Randomly Undersampled and Tuned Decision Tree model model on X_test:
# Accuracy: 0.93539
# Specificity: 0.98185
# Precision: 0.94340
# Recall: 0.81081
